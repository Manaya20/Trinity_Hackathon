# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv(r'claims_and_patient.csv')

# %%
df = df.fillna(df.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df = df.fillna(df.mean())
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df
# Out:
#       claim id claim date  claim line item claim status  \
# 0        41439   12/27/18                1
# 1        98850     9/2/21                1
# 2        74412    3/15/18                3
# 3        28608    4/13/19                1
# 4        28608    4/13/19                4
# ...        ...        ...              ...          ...
# 2195     32152    12/8/18                1
# 2196     64341   12/11/18               42
# 2197     64341   12/15/18               24
# 2198     64341   12/14/18               14
# 2199     64341   12/19/18               34
#
#      primary plan payment type secondary plan payment type  \
# 0                     Medicare
# 1                   Commercial
# 2                     Medicare
# 3              Medicare Part D
# 4              Medicare Part D
# ...                        ...                         ...
# 2195                Commercial
# 2196                Commercial
# 2197                Commercial
# 2198                Commercial
# 2199                Commercial
#
#      tertiary plan payment type                 primary plan name  \
# 0                                          MEDICARE MARYLAND (MD)
# 1                                                 UNH-UNSPECIFIED
# 2                                MEDICARE B CALIFORNIA SOUTH (CA)
# 3                                                  UH MED MENERAL
# 4                                                  UH MED MENERAL
# ...                         ...                               ...
# 2195                                           BCS OF CA HMO (CA)
# 2196                                           BCS OF CA HMO (CA)
# 2197                                           BCS OF CA HMO (CA)
# 2198                                           BCS OF CA HMO (CA)
# 2199                                           BCS OF CA HMO (CA)
#
#      secondary plan name secondary plan name.1  ... procedure code  \
# 0                                               ...          71046
# 1                                               ...          E0260
# 2                                               ...          11056
# 3                                               ...          99213
# 4                                               ...          J0696
# ...                  ...                   ...  ...            ...
# 2195                                            ...          71045
# 2196                                            ...          97167
# 2197                                            ...          97110
# 2198                                            ...          85025
# 2199                                            ...          97530
#
#      treatment code                              treatment description  \
# 0             71046             RADIOLOGIC EXAMINATION, CHEST; 2 VIEWS
# 1             E0260  HOSPITAL BED, SEMI-ELECTRIC (HEAD AND FOOT ADJ...
# 2             11056  PARING OR CUTTING OF BENIGN HYPERKERATOTIC LES...
# 3             99213  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 4             J0696          INJECTION, CEFTRIAXONE SODIUM, PER 250 MG
# ...             ...                                                ...
# 2195          71045         RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW
# 2196          97167  OCCUPATIONAL THERAPY EVALUATION, HIGH COMPLEXI...
# 2197          97110  THERAPEUTIC PROCEDURE, 1 OR MORE AREAS, EACH 1...
# 2198          85025  BLOOD COUNT; COMPLETE (CBC), AUTOMATED (HGB, H...
# 2199          97530  THERAPEUTIC ACTIVITIES, DIRECT (ONE-ON-ONE) PA...
#
#      days supply quantity patient id patient year of birth  \
# 0                             122343                  1973
# 1                             146620                  1949
# 2                             150208                     0
# 3                             172631                  1941
# 4                             172631                  1941
# ...          ...      ...        ...                   ...
# 2195                          196185                  1951
# 2196                          196185                  1951
# 2197                          196185                  1951
# 2198                          196185                  1951
# 2199                          196185                  1951
#
#      patient gender source value product id        product name
# 0                              M
# 1                              F
# 2                              F
# 3                              F
# 4                              F  409733801  CEFTRIAXONE SODIUM
# ...                          ...        ...                 ...
# 2195                           M
# 2196                           M
# 2197                           M
# 2198                           M
# 2199                           M
#
# [2200 rows x 48 columns]

# %%
df.head()
# Out:
#    claim id claim date  claim line item claim status  \
# 0     41439   12/27/18                1
# 1     98850     9/2/21                1
# 2     74412    3/15/18                3
# 3     28608    4/13/19                1
# 4     28608    4/13/19                4
#
#   primary plan payment type secondary plan payment type  \
# 0                  Medicare
# 1                Commercial
# 2                  Medicare
# 3           Medicare Part D
# 4           Medicare Part D
#
#   tertiary plan payment type                 primary plan name  \
# 0                                       MEDICARE MARYLAND (MD)
# 1                                              UNH-UNSPECIFIED
# 2                             MEDICARE B CALIFORNIA SOUTH (CA)
# 3                                               UH MED MENERAL
# 4                                               UH MED MENERAL
#
#   secondary plan name secondary plan name.1  ... procedure code  \
# 0                                            ...          71046
# 1                                            ...          E0260
# 2                                            ...          11056
# 3                                            ...          99213
# 4                                            ...          J0696
#
#   treatment code                              treatment description  \
# 0          71046             RADIOLOGIC EXAMINATION, CHEST; 2 VIEWS
# 1          E0260  HOSPITAL BED, SEMI-ELECTRIC (HEAD AND FOOT ADJ...
# 2          11056  PARING OR CUTTING OF BENIGN HYPERKERATOTIC LES...
# 3          99213  OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 4          J0696          INJECTION, CEFTRIAXONE SODIUM, PER 250 MG
#
#   days supply quantity patient id patient year of birth  \
# 0                          122343                  1973
# 1                          146620                  1949
# 2                          150208                     0
# 3                          172631                  1941
# 4                          172631                  1941
#
#   patient gender source value product id        product name
# 0                           M
# 1                           F
# 2                           F
# 3                           F
# 4                           F  409733801  CEFTRIAXONE SODIUM
#
# [5 rows x 48 columns]

# %%
df.describe()
# Out:
#            claim id  claim line item     patient id  patient year of birth
# count   2200.000000      2200.000000    2200.000000            2200.000000
# mean   56335.252727         7.629091  144513.083182            1686.057727
# std    26786.013965        11.269434   28041.852752             672.828406
# min    10194.000000         0.000000  100525.000000               0.000000
# 25%    33922.000000         1.000000  123424.000000            1944.000000
# 50%    57461.000000         3.000000  137748.000000            1949.000000
# 75%    82179.000000         8.000000  164700.000000            1957.000000
# max    99930.000000        65.000000  199968.000000            2022.000000

# %%
df.dtypes
# Out:
# claim id                         int64
# claim date                      object
# claim line item                  int64
# claim status                    object
# primary plan payment type       object
# secondary plan payment type     object
# tertiary plan payment type      object
# primary plan name               object
# secondary plan name             object
# secondary plan name.1           object
# tertiary plan name              object
# primary plan type               object
# secondary plan type             object
# tertiary plan type              object
# reject code                     object
# reject reason                   object
# source claim type               object
# referring provider doctor id    object
# rendering provider doctor id    object
# diagnosis code 1                object
# diagnosis code 2                object
# diagnosis code 3                object
# diagnosis code 4                object
# diagnosis code 5                object
# diagnosis code 6                object
# diagnosis code 7                object
# diagnosis code 8                object
# patient oop                     object
# buy down                        object
# paid by payer                   object
# service bill amount             object
# service allowed amount          object
# out of pocket ask               object
# primary payer pay amount        object
# secondary payer pay amount      object
# tertiary payer pay amount       object
# product strength                object
# procedure description           object
# procedure code                  object
# treatment code                  object
# treatment description           object
# days supply                     object
# quantity                        object
# patient id                       int64
# patient year of birth            int64
# patient gender source value     object
# product id                      object
# product name                    object
# dtype: object

# %%
df["Patient age"] = 2024 - df["patient year of birth"]

# %%
df.dtypes
# Out:
# claim id                         int64
# claim date                      object
# claim line item                  int64
# claim status                    object
# primary plan payment type       object
# secondary plan payment type     object
# tertiary plan payment type      object
# primary plan name               object
# secondary plan name             object
# secondary plan name.1           object
# tertiary plan name              object
# primary plan type               object
# secondary plan type             object
# tertiary plan type              object
# reject code                     object
# reject reason                   object
# source claim type               object
# referring provider doctor id    object
# rendering provider doctor id    object
# diagnosis code 1                object
# diagnosis code 2                object
# diagnosis code 3                object
# diagnosis code 4                object
# diagnosis code 5                object
# diagnosis code 6                object
# diagnosis code 7                object
# diagnosis code 8                object
# patient oop                     object
# buy down                        object
# paid by payer                   object
# service bill amount             object
# service allowed amount          object
# out of pocket ask               object
# primary payer pay amount        object
# secondary payer pay amount      object
# tertiary payer pay amount       object
# product strength                object
# procedure description           object
# procedure code                  object
# treatment code                  object
# treatment description           object
# days supply                     object
# quantity                        object
# patient id                       int64
# patient year of birth            int64
# patient gender source value     object
# product id                      object
# product name                    object
# Patient age                      int64
# dtype: object

# %%
df
# Out:
#       claim id claim date  claim line item claim status  \
# 0        41439   12/27/18                1
# 1        98850     9/2/21                1
# 2        74412    3/15/18                3
# 3        28608    4/13/19                1
# 4        28608    4/13/19                4
# ...        ...        ...              ...          ...
# 2195     32152    12/8/18                1
# 2196     64341   12/11/18               42
# 2197     64341   12/15/18               24
# 2198     64341   12/14/18               14
# 2199     64341   12/19/18               34
#
#      primary plan payment type secondary plan payment type  \
# 0                     Medicare
# 1                   Commercial
# 2                     Medicare
# 3              Medicare Part D
# 4              Medicare Part D
# ...                        ...                         ...
# 2195                Commercial
# 2196                Commercial
# 2197                Commercial
# 2198                Commercial
# 2199                Commercial
#
#      tertiary plan payment type                 primary plan name  \
# 0                                          MEDICARE MARYLAND (MD)
# 1                                                 UNH-UNSPECIFIED
# 2                                MEDICARE B CALIFORNIA SOUTH (CA)
# 3                                                  UH MED MENERAL
# 4                                                  UH MED MENERAL
# ...                         ...                               ...
# 2195                                           BCS OF CA HMO (CA)
# 2196                                           BCS OF CA HMO (CA)
# 2197                                           BCS OF CA HMO (CA)
# 2198                                           BCS OF CA HMO (CA)
# 2199                                           BCS OF CA HMO (CA)
#
#      secondary plan name secondary plan name.1  ... treatment code  \
# 0                                               ...          71046
# 1                                               ...          E0260
# 2                                               ...          11056
# 3                                               ...          99213
# 4                                               ...          J0696
# ...                  ...                   ...  ...            ...
# 2195                                            ...          71045
# 2196                                            ...          97167
# 2197                                            ...          97110
# 2198                                            ...          85025
# 2199                                            ...          97530
#
#                                   treatment description days supply quantity  \
# 0                RADIOLOGIC EXAMINATION, CHEST; 2 VIEWS
# 1     HOSPITAL BED, SEMI-ELECTRIC (HEAD AND FOOT ADJ...
# 2     PARING OR CUTTING OF BENIGN HYPERKERATOTIC LES...
# 3     OFFICE OR OTHER OUTPATIENT VISIT FOR THE EVALU...
# 4             INJECTION, CEFTRIAXONE SODIUM, PER 250 MG
# ...                                                 ...         ...      ...
# 2195         RADIOLOGIC EXAMINATION, CHEST; SINGLE VIEW
# 2196  OCCUPATIONAL THERAPY EVALUATION, HIGH COMPLEXI...
# 2197  THERAPEUTIC PROCEDURE, 1 OR MORE AREAS, EACH 1...
# 2198  BLOOD COUNT; COMPLETE (CBC), AUTOMATED (HGB, H...
# 2199  THERAPEUTIC ACTIVITIES, DIRECT (ONE-ON-ONE) PA...
#
#      patient id patient year of birth patient gender source value product id  \
# 0        122343                  1973                           M
# 1        146620                  1949                           F
# 2        150208                     0                           F
# 3        172631                  1941                           F
# 4        172631                  1941                           F  409733801
# ...         ...                   ...                         ...        ...
# 2195     196185                  1951                           M
# 2196     196185                  1951                           M
# 2197     196185                  1951                           M
# 2198     196185                  1951                           M
# 2199     196185                  1951                           M
#
#             product name Patient age
# 0                                 51
# 1                                 75
# 2                               2024
# 3                                 83
# 4     CEFTRIAXONE SODIUM          83
# ...                  ...         ...
# 2195                              73
# 2196                              73
# 2197                              73
# 2198                              73
# 2199                              73
#
# [2200 rows x 49 columns]

# %%
avg_age_by_drug = df.groupby('product name')['Patient age'].mean()

# %%
print(avg_age_by_drug)
# Out:
# product name
# ACETAMINOPHEN                  64.000000
# AVASTIN                      2024.000000
# BETAMETHASONE SODIUM PHOS    2024.000000
# CEFAZOLIN                      64.000000
# CEFTRIAXONE SODIUM             84.000000
# CIPROFLOXACIN I.V.-IN D5W      67.500000
# CYANOCOBALAMIN                563.250000
# DEPO-MEDROL                    47.000000
# DEXAMETHASONE SODIUM PHOS      64.000000
# DIPHENHYDRAMINE HCL            64.000000
# DOTAREM                        67.000000
# EXPAREL                        64.000000
# FENTANYL CITRATE               66.666667
# FERAHEME                       76.000000
# FERRLECIT                      80.000000
# FLUCELVAX QUADRIVALENT 20      63.000000
# FLULAVAL QUADRIVALENT 202      64.000000
# FLUZONE HIGH-DOSE PF 2023      80.000000
# HECTOROL                       80.000000
# HYDROMORPHONE HCL              68.000000
# ISOVUE-300                     72.000000
# KETOROLAC TROMETHAMINE         68.000000
# LACTATED RINGERS               64.000000
# LUCENTIS                       67.000000
# MAGNESIUM SULFATE              71.000000
# MIDAZOLAM HYDROCHLORIDE        64.000000
# OMNIPAQUE                      60.000000
# ONDANSETRON HYDROCHLORIDE      68.000000
# ORTHOVISC                    2024.000000
# PARSABIV                       80.000000
# PENTACEL                        2.000000
# PNEUMOVAX 23/5 DOSE            85.000000
# PREVNAR 13                      2.000000
# PROLIA                         72.000000
# PROPOFOL                       64.000000
# RITUXAN                        70.000000
# ROTATEQ                         2.000000
# SANDOSTATIN LAR DEPOT          13.000000
# SODIUM CHLORIDE                75.000000
# SOLU-MEDROL                    70.000000
# TRIAMCINOLONE ACETONIDE        79.000000
# VITRASE                        84.000000
#                               354.140426
# Name: Patient age, dtype: float64

# %%
unique_patients = df.groupby(["product name", "primary plan payment type"])["Patient age"].nunique().reset_index()

print(unique_patients)
# Out:
#                  product name primary plan payment type  Patient age
# 0               ACETAMINOPHEN              Mgd Medicaid            1
# 1                     AVASTIN           Medicare Part D            1
# 2   BETAMETHASONE SODIUM PHOS           Medicare Part D            1
# 3                   CEFAZOLIN              Mgd Medicaid            1
# 4          CEFTRIAXONE SODIUM                Commercial            1
# 5          CEFTRIAXONE SODIUM           Medicare Part D            1
# 6   CIPROFLOXACIN I.V.-IN D5W                Commercial            1
# 7   CIPROFLOXACIN I.V.-IN D5W           Medicare Part D            1
# 8              CYANOCOBALAMIN                  Medicare            2
# 9              CYANOCOBALAMIN              Mgd Medicaid            1
# 10                DEPO-MEDROL              Mgd Medicaid            1
# 11  DEXAMETHASONE SODIUM PHOS              Mgd Medicaid            1
# 12        DIPHENHYDRAMINE HCL              Mgd Medicaid            1
# 13                    DOTAREM                Commercial            1
# 14                    EXPAREL              Mgd Medicaid            1
# 15           FENTANYL CITRATE                  Medicare            1
# 16           FENTANYL CITRATE              Mgd Medicaid            1
# 17                   FERAHEME                  Medicare            1
# 18                  FERRLECIT                  Medicare            1
# 19  FLUCELVAX QUADRIVALENT 20                  Medicare            1
# 20  FLULAVAL QUADRIVALENT 202              Mgd Medicaid            1
# 21  FLUZONE HIGH-DOSE PF 2023           Medicare Part D            1
# 22                   HECTOROL                  Medicare            1
# 23          HYDROMORPHONE HCL                  Medicare            1
# 24          HYDROMORPHONE HCL              Mgd Medicaid            1
# 25                 ISOVUE-300                  Medicare            1
# 26     KETOROLAC TROMETHAMINE                  Medicare            1
# 27     KETOROLAC TROMETHAMINE              Mgd Medicaid            1
# 28           LACTATED RINGERS              Mgd Medicaid            1
# 29                   LUCENTIS                Commercial            1
# 30          MAGNESIUM SULFATE                Commercial            1
# 31          MAGNESIUM SULFATE                  Medicare            1
# 32    MIDAZOLAM HYDROCHLORIDE              Mgd Medicaid            1
# 33                  OMNIPAQUE           Medicare Part D            1
# 34  ONDANSETRON HYDROCHLORIDE                  Medicare            1
# 35  ONDANSETRON HYDROCHLORIDE              Mgd Medicaid            1
# 36                  ORTHOVISC                  Medicare            1
# 37                   PARSABIV                  Medicare            1
# 38                   PENTACEL              FFS Medicaid            1
# 39        PNEUMOVAX 23/5 DOSE                  Medicare            1
# 40                 PREVNAR 13              FFS Medicaid            1
# 41                     PROLIA                  Medicare            1
# 42                   PROPOFOL              Mgd Medicaid            1
# 43                    RITUXAN                  Medicare            1
# 44                    ROTATEQ              FFS Medicaid            1
# 45      SANDOSTATIN LAR DEPOT                  Medicare            1
# 46            SODIUM CHLORIDE                Commercial            1
# 47                SOLU-MEDROL                  Medicare            1
# 48    TRIAMCINOLONE ACETONIDE                Commercial            1
# 49                    VITRASE                  Medicare            1
# 50                                           Commercial           46
# 51                                         FFS Medicaid            6
# 52                                             Medicare           28
# 53                                      Medicare Part D           16
# 54                                         Mgd Medicaid           18
# 55                                      Unknown Medical            3
